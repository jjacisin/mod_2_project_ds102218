# %%
import pandas as pd
import glob

# %%
df_sen = pd.read_csv('results_csvs/US_Sen.csv')
df_tx_gov = pd.read_csv('results_csvs/TX_Gov.csv')
df_tx_09 = pd.read_csv('results_csvs/TX_9.csv')
df_tx_30 = pd.read_csv('results_csvs/TX_30.csv')

# %%
df_tx_gov
# Out:
#      Unnamed: 0        County      REP      DEM     LIB  Total Votes  \
# 0             3  ALL COUNTIES  4638582  3528705  140125      8307412
# 1             5      ANDERSON    11710     2849     149        14708
# 2             7       ANDREWS     3400      687      38         4125
# 3             9      ANGELINA    19689     6401     243        26333
# 4            11       ARANSAS     7044     1782     106         8932
# 5            13        ARCHER     3259      323      28         3610
# 6            15     ARMSTRONG      822       59      14          895
# 7            17      ATASCOSA     8345     3649     157        12151
# 8            19        AUSTIN     8988     1894     123        11005
# 9            21        BAILEY     1239      348      17         1604
# 10           23       BANDERA     7866     1600     120         9586
# 11           25       BASTROP    16332    10392     640        27364
# 12           27        BAYLOR     1090      129      15         1234
# 13           29           BEE     4827     2259      90         7176
# 14           31          BELL    50992    33612    1434        86038
# 15           33         BEXAR   249781   283755    9791       543327
# 16           35        BLANCO     4327     1349     115         5791
# 17           37        BORDEN      321       17       1          339
# 18           39        BOSQUE     5929     1095     106         7130
# 19           41         BOWIE    20625     7336     281        28242
# 20           43      BRAZORIA    70139    39395    1633       111167
# 21           45        BRAZOS    39141    23189    1369        63699
# 22           47      BREWSTER     2022     1930      96         4048
# 23           49       BRISCOE      556       58       9          623
# 24           51        BROOKS      658     1198      12         1868
# 25           53         BROWN    10635     1457     142        12234
# 26           55      BURLESON     5252     1275      68         6595
# 27           57        BURNET    14423     3692     340        18455
# 28           59      CALDWELL     6706     4496     223        11425
# 29           61       CALHOUN     4409     1627      82         6118
# ..          ...           ...      ...      ...     ...          ...
# 225         453         TITUS     5828     2010      96         7934
# 226         455     TOM GREEN    25705     8314     486        34505
# 227         457        TRAVIS   145105   318120   13311       476536
# 228         459       TRINITY     4293      835      41         5169
# 229         461         TYLER     6033      965      67         7065
# 230         463        UPSHUR    11625     2175     193        13993
# 231         465         UPTON      859      148       8         1015
# 232         467        UVALDE     4747     3054      80         7881
# 233         469     VAL VERDE     5938     5205     128        11271
# 234         471     VAN ZANDT    15606     2148     190        17944
# 235         473      VICTORIA    19588     7238     303        27129
# 236         475        WALKER    12179     5311     266        17756
# 237         477        WALLER    10616     5774     168        16558
# 238         479          WARD     2198      689      34         2921
# 239         481    WASHINGTON    10526     2725     208        13459
# 240         483          WEBB    16286    32044     569        48899
# 241         485       WHARTON     9470     3327     107        12904
# 242         487       WHEELER     1682      126      13         1821
# 243         489       WICHITA    24787     8594     489        33870
# 244         491     WILBARGER     2721      685      50         3456
# 245         493       WILLACY     1931     2257      38         4226
# 8                 19
# 9                  5
# 10                11
# 11                22
# 12                 5
# 13                11
# 14                49
# 15               753
# 16                 7
# 17                 8
# 18                12
# 19                33
# 20                27
# 21                27
# 22                 9
# 23                 6
# 24                10
# 25                20
# 26                14
# 27                21
# 28                32
# 29                26
# ..               ...
# 225               20
# 226               20
# 227              159
# 228               21
# 229               18
# 230               17
# 231                7
# 232               15
# 233               18
# 234               18
# 235               36
# 236               17
# 237               21
# 238                9
# 239               22
# 240               69
# 241                9
# 242               11
# 243               62
# 244                6
# 245               18
# 246               60
# 247               17
# 248                6
# 249               26
# 250               14
# 251                7
# 252                9
# 253                8
# 254                7
#
# [255 rows x 11 columns]

# %%
df_tx_09.columns
# Out:
# Index(['Unnamed: 0', 'County', 'DEM', 'LIB', 'IND', 'IND.1', 'Total Votes',
#        'Precincts Reported', 'Total Precincts'],
#       dtype='object')

# %%
new_columns = ["REP","Total Votes","R_%"]
test_list = [df_sen,df_tx_09,df_tx_gov]

# %%
# path =r'C:\DRO\DCL_rawdata_files' # use your path
# allFiles = glob.glob(path + "/*.csv")

# list_ = []

# for file_ in allFiles:
#     df = pd.read_csv(file_,index_col=None, header=0)
#     list_.append(df)

# %%
#test adding information to a df outside of a for loop
df_list = []
for data in test_list:
    df_dict = {}
    if "REP" in data.columns:
        df_dict["REP"] = data[data["County"]=="ALL COUNTIES"]["REP"][0]
    else:
        df_dict["REP"] = 0
    df_dict["Total Votes"] =  data[data["County"]=="ALL COUNTIES"]["Total Votes"][0]
    df_list.append(df_dict)
    

pd.DataFrame(df_list)
# Out:
#        REP  Total Votes
# 0  4244204      8334221
# 1        0       152653
# 2  4638582      8307412

# %%
path = '/Users/jim_jack/Documents/mod_2_project/mod_2_project_ds102218/results_csvs'
allFiles = glob.glob(path + "/*.csv")
lower = str.rfind(allFiles[0],'/')+1
upper = str.rfind(allFiles[0],'.')
allFiles[0][lower:upper]
# Out:
# 'TX_32'

# %%
test_name = 'Users/jim_jack/Documents/mod_2_project/mod_2_project_ds102218/results_csvs/TX_32.cs'
def file_name_finder(file_name):
    lower = str.rfind(file_name,'/')+1

    upper = str.rfind(file_name,'.')

    return file_name[lower:upper]

# %%
path = '/Users/jim_jack/Documents/mod_2_project/mod_2_project_ds102218/results_csvs'
allFiles = glob.glob(path + "/*.csv")
allFiles
# one = allFiles[7]
# df_one = pd.read_csv(one)
# df_one[df_one["County"]=="ALL COUNTIES"]
# Out:
# ['/Users/jim_jack/Documents/mod_2_project/mod_2_project_ds102218/results_csvs/TX_32.csv',
#  '/Users/jim_jack/Documents/mod_2_project/mod_2_project_ds102218/results_csvs/TX_26.csv',
#  '/Users/jim_jack/Documents/mod_2_project/mod_2_project_ds102218/results_csvs/TX_27.csv',
#  '/Users/jim_jack/Documents/mod_2_project/mod_2_project_ds102218/results_csvs/TX_33.csv',
#  '/Users/jim_jack/Documents/mod_2_project/mod_2_project_ds102218/results_csvs/TX_19.csv',
#  '/Users/jim_jack/Documents/mod_2_project/mod_2_project_ds102218/results_csvs/TX_25.csv',
#  '/Users/jim_jack/Documents/mod_2_project/mod_2_project_ds102218/results_csvs/TX_31.csv',
#  '/Users/jim_jack/Documents/mod_2_project/mod_2_project_ds102218/results_csvs/TX_30.csv',
#  '/Users/jim_jack/Documents/mod_2_project/mod_2_project_ds102218/results_csvs/TX_24.csv',
#  '/Users/jim_jack/Documents/mod_2_project/mod_2_project_ds102218/results_csvs/TX_18.csv',
#  '/Users/jim_jack/Documents/mod_2_project/mod_2_project_ds102218/results_csvs/TX_20.csv',
#  '/Users/jim_jack/Documents/mod_2_project/mod_2_project_ds102218/results_csvs/TX_34.csv',
#  '/Users/jim_jack/Documents/mod_2_project/mod_2_project_ds102218/results_csvs/TX_35.csv',
#  '/Users/jim_jack/Documents/mod_2_project/mod_2_project_ds102218/results_csvs/TX_21.csv',
#  '/Users/jim_jack/Documents/mod_2_project/mod_2_project_ds102218/results_csvs/TX_23.csv',
#  '/Users/jim_jack/Documents/mod_2_project/mod_2_project_ds102218/results_csvs/TX_22.csv',
#  '/Users/jim_jack/Documents/mod_2_project/mod_2_project_ds102218/results_csvs/TX_36.csv',
#  '/Users/jim_jack/Documents/mod_2_project/mod_2_project_ds102218/results_csvs/TX_8.csv',
#  '/Users/jim_jack/Documents/mod_2_project/mod_2_project_ds102218/results_csvs/TX_9.csv',
#  '/Users/jim_jack/Documents/mod_2_project/mod_2_project_ds102218/results_csvs/TX_4.csv',
#  '/Users/jim_jack/Documents/mod_2_project/mod_2_project_ds102218/results_csvs/TX_5.csv',
#  '/Users/jim_jack/Documents/mod_2_project/mod_2_project_ds102218/results_csvs/TX_7.csv',
#  '/Users/jim_jack/Documents/mod_2_project/mod_2_project_ds102218/results_csvs/US_Sen.csv',
#  '/Users/jim_jack/Documents/mod_2_project/mod_2_project_ds102218/results_csvs/TX_6.csv',
#  '/Users/jim_jack/Documents/mod_2_project/mod_2_project_ds102218/results_csvs/TX_2.csv',
#  '/Users/jim_jack/Documents/mod_2_project/mod_2_project_ds102218/results_csvs/TX_3.csv',
#  '/Users/jim_jack/Documents/mod_2_project/mod_2_project_ds102218/results_csvs/TX_1.csv',
#  '/Users/jim_jack/Documents/mod_2_project/mod_2_project_ds102218/results_csvs/TX_13.csv',
#  '/Users/jim_jack/Documents/mod_2_project/mod_2_project_ds102218/results_csvs/TX_12.csv',
#  '/Users/jim_jack/Documents/mod_2_project/mod_2_project_ds102218/results_csvs/TX_10.csv',
#  '/Users/jim_jack/Documents/mod_2_project/mod_2_project_ds102218/results_csvs/TX_11.csv',
#  '/Users/jim_jack/Documents/mod_2_project/mod_2_project_ds102218/results_csvs/TX_15.csv',
#  '/Users/jim_jack/Documents/mod_2_project/mod_2_project_ds102218/results_csvs/TX_29.csv',
#  '/Users/jim_jack/Documents/mod_2_project/mod_2_project_ds102218/results_csvs/TX_28.csv',
#  '/Users/jim_jack/Documents/mod_2_project/mod_2_project_ds102218/results_csvs/TX_14.csv',
#  '/Users/jim_jack/Documents/mod_2_project/mod_2_project_ds102218/results_csvs/TX_16.csv',
#  '/Users/jim_jack/Documents/mod_2_project/mod_2_project_ds102218/results_csvs/TX_17.csv',
#  '/Users/jim_jack/Documents/mod_2_project/mod_2_project_ds102218/results_csvs/TX_Gov.csv']

# %%
def create_summary_df():
    path = '/Users/jim_jack/Documents/mod_2_project/mod_2_project_ds102218/results_csvs'
    allFiles = glob.glob(path + "/*.csv")
    df_summary = []
    for data in allFiles:
        df_dict = {}
        local_df = pd.read_csv(data)
        df_dict['Race'] = file_name_finder(data)
        if "REP" in local_df.columns:
            df_dict['REP'] = local_df.iloc[0]["REP"]
        else:
            df_dict["REP"] = 0
        df_dict['Total Votes'] = local_df.iloc[0]["Total Votes"]
        df_summary.append(df_dict)
    return pd.DataFrame(df_summary)

# %%
df_draft = create_summary_df()
df_draft
# Out:
#         REP    Race  Total Votes
# 0    125600   TX_32       273909
# 1    185268   TX_26       311860
# 2    124958   TX_27       207079
# 3     26007   TX_33       118609
# 4    152012   TX_19       201953
# 5    162288   TX_25       302700
# 6    144393   TX_31       285191
# 7         0   TX_30       182420
# 8    132992   TX_24       262433
# 9     38306   TX_18       183978
# 10        0   TX_20       170976
# 11    57157   TX_34       142804
# 12    50276   TX_35       192816
# 13   176913   TX_21       351430
# 14   102903   TX_23       209058
# 15   152368   TX_22       296449
# 16   160783   TX_36       221534
# 17   200367    TX_8       272732
# 18        0    TX_9       152653
# 19   188003    TX_4       248373
# 20   130404    TX_5       209147
# 21   115418    TX_7       242986
# 22  4244204  US_Sen      8334221
# 23   135779    TX_6       255543
# 24   139012    TX_2       262924
# 25   168775    TX_3       311070
# 26   167734    TX_1       231969
# 27   168090   TX_13       206093
# 28   172205   TX_12       267807
# 29   154807   TX_10       304111
# 30   174749   TX_11       217883
# 31    63593   TX_15       164284
# 32    28045   TX_29       117246
# 33        0   TX_28       138825
# 34   137582   TX_14       231873
# 35    48495   TX_16       179619
# 36   134375   TX_17       236364
# 37  4638582  TX_Gov      8307412

# %%
def add_leading_zero(row):
    if len(row) == 4:
        return row[0:3] +str(0) + row[-1] 
    else:
        return row

# %%
df_draft["Race"] = df_draft["Race"].apply(add_leading_zero)
df_draft
# df.loc[df['First Season'] > 1990, 'First Season'] = 1
# Out:
#         REP    Race  Total Votes
# 0    125600   TX_32       273909
# 1    185268   TX_26       311860
# 2    124958   TX_27       207079
# 3     26007   TX_33       118609
# 4    152012   TX_19       201953
# 5    162288   TX_25       302700
# 6    144393   TX_31       285191
# 7         0   TX_30       182420
# 8    132992   TX_24       262433
# 9     38306   TX_18       183978
# 10        0   TX_20       170976
# 11    57157   TX_34       142804
# 12    50276   TX_35       192816
# 13   176913   TX_21       351430
# 14   102903   TX_23       209058
# 15   152368   TX_22       296449
# 16   160783   TX_36       221534
# 17   200367   TX_08       272732
# 18        0   TX_09       152653
# 19   188003   TX_04       248373
# 20   130404   TX_05       209147
# 21   115418   TX_07       242986
# 22  4244204  US_Sen      8334221
# 23   135779   TX_06       255543
# 24   139012   TX_02       262924
# 25   168775   TX_03       311070
# 26   167734   TX_01       231969
# 27   168090   TX_13       206093
# 28   172205   TX_12       267807
# 29   154807   TX_10       304111
# 30   174749   TX_11       217883
# 31    63593   TX_15       164284
# 32    28045   TX_29       117246
# 33        0   TX_28       138825
# 34   137582   TX_14       231873
# 35    48495   TX_16       179619
# 36   134375   TX_17       236364
# 37  4638582  TX_Gov      8307412

# %%
df_cleaned = df_draft.set_index("Race")
df_sorted = df_cleaned.sort_index()
df_sorted
# Out:
#             REP  Total Votes
# Race
# TX_01    167734       231969
# TX_02    139012       262924
# TX_03    168775       311070
# TX_04    188003       248373
# TX_05    130404       209147
# TX_06    135779       255543
# TX_07    115418       242986
# TX_08    200367       272732
# TX_09         0       152653
# TX_10    154807       304111
# TX_11    174749       217883
# TX_12    172205       267807
# TX_13    168090       206093
# TX_14    137582       231873
# TX_15     63593       164284
# TX_16     48495       179619
# TX_17    134375       236364
# TX_18     38306       183978
# TX_19    152012       201953
# TX_20         0       170976
# TX_21    176913       351430
# TX_22    152368       296449
# TX_23    102903       209058
# TX_24    132992       262433
# TX_25    162288       302700
# TX_26    185268       311860
# TX_27    124958       207079
# TX_28         0       138825
# TX_29     28045       117246
# TX_30         0       182420
# TX_31    144393       285191
# TX_32    125600       273909
# TX_33     26007       118609
# TX_34     57157       142804
# TX_35     50276       192816
# TX_36    160783       221534
# TX_Gov  4638582      8307412
# US_Sen  4244204      8334221

# %%
def prop_r_vote(row):
    return int(row['REP'])/int(row['Total Votes'])
df_sorted['prop_r_vote'] = df_sorted.apply(lambda row: prop_r_vote(row),axis=1)

# %%
df_sorted
# Out:
#             REP  Total Votes  prop_r_vote
# Race
# TX_01    167734       231969     0.723088
# TX_02    139012       262924     0.528716
# TX_03    168775       311070     0.542563
# TX_04    188003       248373     0.756938
# TX_05    130404       209147     0.623504
# TX_06    135779       255543     0.531335
# TX_07    115418       242986     0.474999
# TX_08    200367       272732     0.734666
# TX_09         0       152653     0.000000
# TX_10    154807       304111     0.509048
# TX_11    174749       217883     0.802031
# TX_12    172205       267807     0.643019
# TX_13    168090       206093     0.815603
# TX_14    137582       231873     0.593351
# TX_15     63593       164284     0.387092
# TX_16     48495       179619     0.269988
# TX_17    134375       236364     0.568509
# TX_18     38306       183978     0.208210
# TX_19    152012       201953     0.752710
# TX_20         0       170976     0.000000
# TX_21    176913       351430     0.503409
# TX_22    152368       296449     0.513977
# TX_23    102903       209058     0.492222
# TX_24    132992       262433     0.506766
# TX_25    162288       302700     0.536135
# TX_26    185268       311860     0.594074
# TX_27    124958       207079     0.603432
# TX_28         0       138825     0.000000
# TX_29     28045       117246     0.239198
# TX_30         0       182420     0.000000
# TX_31    144393       285191     0.506303
# TX_32    125600       273909     0.458546
# TX_33     26007       118609     0.219267
# TX_34     57157       142804     0.400248
# TX_35     50276       192816     0.260746
# TX_36    160783       221534     0.725771
# TX_Gov  4638582      8307412     0.558367
# US_Sen  4244204      8334221     0.509250

# %%
# df_sorted.to_csv('/Users/jim_jack/Documents/mod_2_project/mod_2_project_ds102218/election_data.csv')
